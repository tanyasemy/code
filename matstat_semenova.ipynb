# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from scipy import stats
import random

# %% [markdown]
# без поправок

# %%
df=pd.DataFrame()
for i in range(20):
    df[i]=np.random.normal(0,4,10000)

# %%
def ttest(a,b,n):
    mean_diff = np.mean(a) - np.mean(b)
    n1 = len(a)
    n2 = len(b)
    sd_a = np.sqrt(np.var(a,ddof = 1))
    sd_b = np.sqrt(np.var(b,ddof = 1))
    sem = np.sqrt(sd_a**2/n1 + sd_b**2/n2)
    t = mean_diff/sem
    df = (n1 + n2) - 2
    p = stats.t.cdf(-abs(t), df) * 2 
    j=0
    if p > 0.05/n:
        print('Нет статистически значимой разницы','\nt - критерий = ',t,'\np-value =',p)
    else:
        print('Есть статистически значимая разница','\nt - критерий = ',t,'\np-value =',p)
        j=1
    return j

# %%
n = 10
num = 0
for i in range(n):
    for j  in range(n):
        if i!=j & j < i:
            num = num + ttest(df[i],df[j],n)
print(num)
# Out:
# Нет статистически значимой разницы
# t - критерий =  0.32553196850024047
# p-value = 0.7447818974338903
# Нет статистически значимой разницы
# t - критерий =  -0.10694228742070469
# p-value = 0.9148358377669804
# Нет статистически значимой разницы
# t - критерий =  -0.43106267615926724
# p-value = 0.6664274445878433
# Нет статистически значимой разницы
# t - критерий =  -0.08088703503991991
# p-value = 0.9355326001511621
# Нет статистически значимой разницы
# t - критерий =  -0.40507758430007246
# p-value = 0.6854248157104781
# Нет статистически значимой разницы
# t - критерий =  0.025966114811773067
# p-value = 0.9792846248817062
# Нет статистически значимой разницы
# t - критерий =  1.8165305096933442
# p-value = 0.06930399614885727
# Нет статистически значимой разницы
# t - критерий =  1.4930553271301135
# p-value = 0.13543848080517595
# Нет статистически значимой разницы
# t - критерий =  1.9150551359737729
# p-value = 0.05549972153980834
# Нет статистически значимой разницы
# t - критерий =  1.8895481939662249
# p-value = 0.058832862790596144
# Нет статистически значимой разницы
# t - критерий =  1.8275561361924955
# p-value = 0.0676310872405093
# Нет статистически значимой разницы
# t - критерий =  1.5038907252569367
# p-value = 0.13262529719373808
# Нет статистически значимой разницы
# t - критерий =  1.9260869099617874
# p-value = 0.05410768090223579
# Нет статистически значимой разницы
# t - критерий =  1.9005676462310421
# p-value = 0.05737303201712191
# Нет статистически значимой разницы
# t - критерий =  0.00990000709258126
# p-value = 0.9921011649708509
# Нет статистически значимой разницы
# t - критерий =  0.5623639180276299
# p-value = 0.573874400777477
# Нет статистически значимой разницы
# t - критерий =  0.23633989713126455
# p-value = 0.8131713507271503
# Нет статистически значимой разницы
# t - критерий =  0.6670223511497277
# p-value = 0.5047655525603576
# Нет статистически значимой разницы
# t - критерий =  0.6410495428543697
# p-value = 0.5214978411517249
# Нет статистически значимой разницы
# t - критерий =  -1.260428190152271
# p-value = 0.20752964400951526
# Нет статистически значимой разницы
# t - критерий =  -1.2711439309637944
# p-value = 0.20369223405142386
# Нет статистически значимой разницы
# t - критерий =  0.2115533057305913
# p-value = 0.8324576971292994
# Нет статистически значимой разницы
# t - критерий =  -0.11231682843785043
# p-value = 0.9105733263696074
# Нет статистически значимой разницы
# t - критерий =  0.31704537273171063
# p-value = 0.7512124839689567
# Нет статистически значимой разницы
# t - критерий =  0.2911671469529153
# p-value = 0.7709265071735687
# Нет статистически значимой разницы
# t - критерий =  -1.5971801377272303
# p-value = 0.11024135873531532
# Нет статистически значимой разницы
# t - критерий =  -1.6080175569109727
# p-value = 0.10784711977789078
# Нет статистически значимой разницы
# t - критерий =  -0.3476163870979764
# p-value = 0.72813195623738
# Нет статистически значимой разницы
# t - критерий =  0.8487575302657623
# p-value = 0.3960263859861586
# Нет статистически значимой разницы
# t - критерий =  0.5228913921517476
# p-value = 0.6010556280571371
# Нет статистически значимой разницы
# t - критерий =  0.9521261145707076
# p-value = 0.34104453375825605
# Нет статистически значимой разницы
# t - критерий =  0.926227386322901
# p-value = 0.3543390003864003
# Нет статистически значимой разницы
# t - критерий =  -0.9749726819909922
# p-value = 0.32958560401108516
# Нет статистически значимой разницы
# t - критерий =  -0.9855152693627962
# p-value = 0.32438295796220096
# Нет статистически значимой разницы
# t - критерий =  0.28709867440889436
# p-value = 0.7740397416924595
# Нет статистически значимой разницы
# t - критерий =  0.6326536588181746
# p-value = 0.5269670716270471
# Нет статистически значимой разницы
# t - критерий =  0.612572156534465
# p-value = 0.5401662387976204
# Нет статистически значимой разницы
# t - критерий =  0.28683265960091264
# p-value = 0.7742434260438743
# Нет статистически значимой разницы
# t - критерий =  0.7169245725638558
# p-value = 0.4734290118480645
# Нет статистически значимой разницы
# t - критерий =  0.6909849413352284
# p-value = 0.48958302477597304
# Нет статистически значимой разницы
# t - критерий =  -1.2089694225460648
# p-value = 0.22668888645800814
# Нет статистически значимой разницы
# t - критерий =  -1.21964513803954
# p-value = 0.22261381121720283
# Нет статистически значимой разницы
# t - критерий =  0.050775252577365725
# p-value = 0.9595051181248213
# Нет статистически значимой разницы
# t - критерий =  0.39775663512462417
# p-value = 0.6908138311767316
# Нет статистически значимой разницы
# t - критерий =  -0.23609766268325336
# p-value = 0.8133593054658456
# 0

# %% [markdown]
# при n<10 - нет пар со значимыми различиями
# при n > 10 - есть одна-две пары со значимыми различиями

# %% [markdown]
# Поправка Бонферрони

# %%
df1=pd.DataFrame()
for i in range(20):
    df1[i]=np.random.normal(np.random.random(),np.random.randint(1,3),1000)

# %%
n = 20
num = 0
for i in range(n):
    for j  in range(n):
        if i!=j & j < i:
            num = num + ttest(df[i],df[j],n)
print(num)
# Out:
# Нет статистически значимой разницы
# t - критерий =  0.32553196850024047
# p-value = 0.7447818974338903
# Нет статистически значимой разницы
# t - критерий =  -0.10694228742070469
# p-value = 0.9148358377669804
# Нет статистически значимой разницы
# t - критерий =  -0.43106267615926724
# p-value = 0.6664274445878433
# Нет статистически значимой разницы
# t - критерий =  -0.08088703503991991
# p-value = 0.9355326001511621
# Нет статистически значимой разницы
# t - критерий =  -0.40507758430007246
# p-value = 0.6854248157104781
# Нет статистически значимой разницы
# t - критерий =  0.025966114811773067
# p-value = 0.9792846248817062
# Нет статистически значимой разницы
# t - критерий =  1.8165305096933442
# p-value = 0.06930399614885727
# Нет статистически значимой разницы
# t - критерий =  1.4930553271301135
# p-value = 0.13543848080517595
# Нет статистически значимой разницы
# t - критерий =  1.9150551359737729
# p-value = 0.05549972153980834
# Нет статистически значимой разницы
# t - критерий =  1.8895481939662249
# p-value = 0.058832862790596144
# Нет статистически значимой разницы
# t - критерий =  1.8275561361924955
# p-value = 0.0676310872405093
# Нет статистически значимой разницы
# t - критерий =  1.5038907252569367
# p-value = 0.13262529719373808
# Нет статистически значимой разницы
# t - критерий =  1.9260869099617874
# p-value = 0.05410768090223579
# Нет статистически значимой разницы
# t - критерий =  1.9005676462310421
# p-value = 0.05737303201712191
# Нет статистически значимой разницы
# t - критерий =  0.00990000709258126
# p-value = 0.9921011649708509
# Нет статистически значимой разницы
# t - критерий =  0.5623639180276299
# p-value = 0.573874400777477
# Нет статистически значимой разницы
# t - критерий =  0.23633989713126455
# p-value = 0.8131713507271503
# Нет статистически значимой разницы
# t - критерий =  0.6670223511497277
# p-value = 0.5047655525603576
# Нет статистически значимой разницы
# t - критерий =  0.6410495428543697
# p-value = 0.5214978411517249
# Нет статистически значимой разницы
# t - критерий =  -1.260428190152271
# p-value = 0.20752964400951526
# Нет статистически значимой разницы
# t - критерий =  -1.2711439309637944
# p-value = 0.20369223405142386
# Нет статистически значимой разницы
# t - критерий =  0.2115533057305913
# p-value = 0.8324576971292994
# Нет статистически значимой разницы
# t - критерий =  -0.11231682843785043
# p-value = 0.9105733263696074
# Нет статистически значимой разницы
# t - критерий =  0.31704537273171063
# p-value = 0.7512124839689567
# Нет статистически значимой разницы
# t - критерий =  0.2911671469529153
# p-value = 0.7709265071735687
# Нет статистически значимой разницы
# t - критерий =  -1.5971801377272303
# p-value = 0.11024135873531532
# Нет статистически значимой разницы
# t - критерий =  -1.6080175569109727
# p-value = 0.10784711977789078
# Нет статистически значимой разницы
# t - критерий =  -0.3476163870979764
# p-value = 0.72813195623738
# Нет статистически значимой разницы
# t - критерий =  0.8487575302657623
# p-value = 0.3960263859861586
# Нет статистически значимой разницы
# t - критерий =  0.5228913921517476
# p-value = 0.6010556280571371
# Нет статистически значимой разницы
# t - критерий =  0.9521261145707076
# p-value = 0.34104453375825605
# Нет статистически значимой разницы
# t - критерий =  0.926227386322901
# p-value = 0.3543390003864003
# Нет статистически значимой разницы
# t - критерий =  -0.9749726819909922
# p-value = 0.32958560401108516
# Нет статистически значимой разницы
# t - критерий =  -0.9855152693627962
# p-value = 0.32438295796220096
# Нет статистически значимой разницы
# t - критерий =  0.28709867440889436
# p-value = 0.7740397416924595
# Нет статистически значимой разницы
# t - критерий =  0.6326536588181746
# p-value = 0.5269670716270471
# Нет статистически значимой разницы
# t - критерий =  0.612572156534465
# p-value = 0.5401662387976204
# Нет статистически значимой разницы
# t - критерий =  0.28683265960091264
# p-value = 0.7742434260438743
# Нет статистически значимой разницы
# t - критерий =  0.7169245725638558
# p-value = 0.4734290118480645
# Нет статистически значимой разницы
# t - критерий =  0.6909849413352284
# p-value = 0.48958302477597304
# Нет статистически значимой разницы
# t - критерий =  -1.2089694225460648
# p-value = 0.22668888645800814
# Нет статистически значимой разницы
# t - критерий =  -1.21964513803954
# p-value = 0.22261381121720283
# Нет статистически значимой разницы
# t - критерий =  0.050775252577365725
# p-value = 0.9595051181248213
# Нет статистически значимой разницы
# t - критерий =  0.39775663512462417
# p-value = 0.6908138311767316
# Нет статистически значимой разницы
# t - критерий =  -0.23609766268325336
# p-value = 0.8133593054658456
# Нет статистически значимой разницы
# t - критерий =  1.222562541775918
# p-value = 0.22150937650709734
# Нет статистически значимой разницы
# t - критерий =  0.896985230230026
# p-value = 0.3697375961874524
# Нет статистически значимой разницы
# t - критерий =  1.3242297726269168
# p-value = 0.18544188013824908
# Нет статистически значимой разницы
# t - критерий =  1.298433848995661
# p-value = 0.19415326689218068
# Нет статистически значимой разницы
# t - критерий =  -0.6019246425829878
# p-value = 0.5472311240081907
# Нет статистически значимой разницы
# t - критерий =  -0.6122391682773991
# p-value = 0.5403864914709211
# Нет статистически значимой разницы
# t - критерий =  0.6619640249581253
# p-value = 0.5080019052616392
# Нет статистически значимой разницы
# t - критерий =  1.004752374436847
# p-value = 0.3150282587537936
# Нет статистически значимой разницы
# t - критерий =  0.3749389873524687
# p-value = 0.7077098189356006
# Нет статистически значимой разницы
# t - критерий =  0.6106827138920123
# p-value = 0.5414165922547363
# Нет статистически значимой разницы
# t - критерий =  -0.4333103996505618
# p-value = 0.6647939574768778
# Нет статистически значимой разницы
# t - критерий =  -0.7585171990064701
# p-value = 0.4481503598997256
# Нет статистически значимой разницы
# t - критерий =  -0.32459504856931237
# p-value = 0.7454909703003161
# Нет статистически значимой разницы
# t - критерий =  -0.3507178957144661
# p-value = 0.7258036926948606
# Нет статистически значимой разницы
# t - критерий =  -2.245318517806174
# p-value = 0.02475857140622115
# Нет статистически значимой разницы
# t - критерий =  -2.256584490558494
# p-value = 0.02404480001931847
# Нет статистически значимой разницы
# t - критерий =  -0.9957662655929059
# p-value = 0.31937577288077795
# Нет статистически значимой разницы
# t - критерий =  -0.6424422494893716
# p-value = 0.5205934396719771
# Нет статистически значимой разницы
# t - критерий =  -1.2816644403167976
# p-value = 0.1999752436934884
# Нет статистически значимой разницы
# t - критерий =  -1.0455466295177827
# p-value = 0.2957830385852456
# Нет статистически значимой разницы
# t - критерий =  -1.6547147579674653
# p-value = 0.09799806469183174
# Нет статистически значимой разницы
# t - критерий =  0.37864550834052324
# p-value = 0.7049551428680947
# Нет статистически значимой разницы
# t - критерий =  0.05388932031500047
# p-value = 0.9570238837542036
# Нет статистически значимой разницы
# t - критерий =  0.4837009540845218
# p-value = 0.6286034122135385
# Нет статистически значимой разницы
# t - критерий =  0.4577884746321945
# p-value = 0.6471093905615943
# Нет статистически значимой разницы
# t - критерий =  -1.436008318131266
# p-value = 0.15101561604097774
# Нет статистически значимой разницы
# t - критерий =  -1.4467830181558794
# p-value = 0.1479733780263979
# Нет статистически значимой разницы
# t - критерий =  -0.1818055393763684
# p-value = 0.8557371798314204
# Нет статистически значимой разницы
# t - критерий =  0.16566783059084705
# p-value = 0.8684200383015449
# Нет статистически значимой разницы
# t - критерий =  -0.467701305314634
# p-value = 0.6400033040083197
# Нет статистически значимой разницы
# t - критерий =  -0.2322259045060483
# p-value = 0.8163649350708099
# Нет статистически значимой разницы
# t - критерий =  -0.8409573550093121
# p-value = 0.40038188024768384
# Нет статистически значимой разницы
# t - критерий =  0.8105468243062213
# p-value = 0.4176356102193909
# Нет статистически значимой разницы
# t - критерий =  -0.4035591191373844
# p-value = 0.6865412676113961
# Нет статистически значимой разницы
# t - критерий =  -0.7267614731510085
# p-value = 0.46738059483299277
# Нет статистически значимой разницы
# t - критерий =  -0.2956479504494385
# p-value = 0.7675020200717694
# Нет статистически значимой разницы
# t - критерий =  -0.32160424986859715
# p-value = 0.7477558850554022
# Нет статистически значимой разницы
# t - критерий =  -2.2047847683604926
# p-value = 0.027480543425458644
# Нет статистически значимой разницы
# t - критерий =  -2.215951190992981
# p-value = 0.026706060340611678
# Нет статистически значимой разницы
# t - критерий =  -0.9624915928461938
# p-value = 0.3358143619601267
# Нет статистически значимой разницы
# t - критерий =  -0.6115782774703998
# p-value = 0.5408237659146702
# Нет статистически значимой разницы
# t - критерий =  -1.2466481171096486
# p-value = 0.21254115198050544
# Нет статистически значимой разницы
# t - критерий =  -1.0119994966558379
# p-value = 0.3115505379885604
# Нет статистически значимой разницы
# t - критерий =  -1.6174469722157654
# p-value = 0.10579760509676316
# Нет статистически значимой разницы
# t - критерий =  0.027048262713568933
# p-value = 0.9784215099084611
# Нет статистически значимой разницы
# t - критерий =  -0.7785581364083329
# p-value = 0.4362492594731543
# Нет статистически значимой разницы
# t - критерий =  1.8771644498258484
# p-value = 0.060510103729631406
# Нет статистически значимой разницы
# t - критерий =  1.5525795098705915
# p-value = 0.12053944837960362
# Нет статистически значимой разницы
# t - критерий =  1.9757391065066479
# p-value = 0.04819805787449709
# Нет статистически значимой разницы
# t - критерий =  1.9501595796875166
# p-value = 0.05117105447352864
# Нет статистически значимой разницы
# t - критерий =  0.05408837472227168
# p-value = 0.9568652946091474
# Нет статистически значимой разницы
# t - критерий =  0.04418642754358307
# p-value = 0.9647562419053729
# Нет статистически значимой разницы
# t - критерий =  1.319249358543333
# p-value = 0.18710086633286216
# Нет статистически значимой разницы
# t - критерий =  1.6567328357948314
# p-value = 0.09758918867691556
# Нет статистически значимой разницы
# t - критерий =  1.0327852997787996
# p-value = 0.3017168740881012
# Нет статистически значимой разницы
# t - критерий =  1.2675599593353886
# p-value = 0.20496989757968098
# Нет статистически значимой разницы
# t - критерий =  0.6584097329368163
# p-value = 0.5102824626062744
# Нет статистически значимой разницы
# t - критерий =  2.30735785770541
# p-value = 0.02104503997420417
# Нет статистически значимой разницы
# t - критерий =  1.4951862148663462
# p-value = 0.13488162942982707
# Нет статистически значимой разницы
# t - критерий =  2.266263430368548
# p-value = 0.023445896969096543
# Нет статистически значимой разницы
# t - критерий =  0.5086514843054953
# p-value = 0.6110021459024
# Нет статистически значимой разницы
# t - критерий =  0.18462991237637438
# p-value = 0.8535211947754153
# Нет статистически значимой разницы
# t - критерий =  0.6129170274557043
# p-value = 0.5399381737793432
# Нет статистически значимой разницы
# t - критерий =  0.5870902041983375
# p-value = 0.5571497539404661
# Нет статистически значимой разницы
# t - критерий =  -1.3027723293361402
# p-value = 0.19266750142871955
# Нет статистически значимой разницы
# t - критерий =  -1.3134437724307417
# p-value = 0.18904852471818523
# Нет статистически значимой разницы
# t - критерий =  -0.05033570972929348
# p-value = 0.9598553702844144
# Нет статистически значимой разницы
# t - критерий =  0.29549859579914406
# p-value = 0.7676160927709829
# Нет статистически значимой разницы
# t - критерий =  -0.3356485317354451
# p-value = 0.7371394429991416
# Нет статистически значимой разницы
# t - критерий =  -0.1007559925509242
# p-value = 0.9197451719037233
# Нет статистически значимой разницы
# t - критерий =  -0.7081807231540501
# p-value = 0.4788412894186199
# Нет статистически значимой разницы
# t - критерий =  0.9394481220907561
# p-value = 0.3475120623533089
# Нет статистически значимой разницы
# t - критерий =  0.130553855910799
# p-value = 0.8961295610058093
# Нет статистически значимой разницы
# t - критерий =  0.9067561274926407
# p-value = 0.3645467004151637
# Нет статистически значимой разницы
# t - критерий =  -1.361355271274053
# p-value = 0.17341678200114202
# Нет статистически значимой разницы
# t - критерий =  0.8029923365439492
# p-value = 0.42198870725088766
# Нет статистически значимой разницы
# t - критерий =  0.4783451698850709
# p-value = 0.6324097809769753
# Нет статистически значимой разницы
# t - критерий =  0.9061874429071738
# p-value = 0.364847566251978
# Нет статистически значимой разницы
# t - критерий =  0.8803743178687057
# p-value = 0.37866714404323276
# Нет статистически значимой разницы
# t - критерий =  -1.0137220891140482
# p-value = 0.31072764526678054
# Нет статистически значимой разницы
# t - критерий =  -1.0242465336936664
# p-value = 0.30573123387063406
# Нет статистически значимой разницы
# t - критерий =  0.24336611645072392
# p-value = 0.8077242861890429
# Нет статистически значимой разницы
# t - критерий =  0.5879364877494284
# p-value = 0.5565815630197402
# Нет статистически значимой разницы
# t - критерий =  -0.0426380851968535
# p-value = 0.9659904611656469
# Нет статистически значимой разницы
# t - критерий =  0.19259443827925596
# p-value = 0.8472785566719916
# Нет статистически значимой разницы
# t - критерий =  -0.416143351005264
# p-value = 0.6773095752824222
# Нет статистически значимой разницы
# t - критерий =  1.234328188732516
# p-value = 0.2170951402785101
# Нет статистически значимой разницы
# t - критерий =  0.42347016802403237
# p-value = 0.6719568137121517
# Нет статистически значимой разницы
# t - критерий =  1.1997598015047786
# p-value = 0.23024685382690396
# Нет статистически значимой разницы
# t - критерий =  -1.071441186927143
# p-value = 0.2839840321935366
# Нет статистически значимой разницы
# t - критерий =  0.2920091248586542
# p-value = 0.7702826763232422
# Нет статистически значимой разницы
# t - критерий =  0.6935979836344303
# p-value = 0.4879424144434803
# Нет статистически значимой разницы
# t - критерий =  0.36834046491409206
# p-value = 0.712623282363813
# Нет статистически значимой разницы
# t - критерий =  0.7974512332090862
# p-value = 0.42519848272298255
# Нет статистически значимой разницы
# t - критерий =  0.7715668494386149
# p-value = 0.44038013156986267
# Нет статистически значимой разницы
# t - критерий =  -1.1257970606875864
# p-value = 0.26026493884699814
# Нет статистически значимой разницы
# t - критерий =  -1.1364075715350703
# p-value = 0.25579964596880833
# Нет статистически значимой разницы
# t - критерий =  0.13275487722735455
# p-value = 0.8943885768337504
# Нет статистически значимой разницы
# t - критерий =  0.47868992916166686
# p-value = 0.6321644647809121
# Нет статистически значимой разницы
# t - критерий =  -0.1537334494478087
# p-value = 0.8778214606554238
# Нет статистически значимой разницы
# t - критерий =  0.08198350855054912
# p-value = 0.9346606480532712
# Нет статистически значимой разницы
# t - критерий =  -0.527839725009485
# p-value = 0.5976164390243475
# Нет статистически значимой разницы
# t - критерий =  1.12585207631819
# p-value = 0.2602416479779459
# Нет статистически значимой разницы
# t - критерий =  0.3136216481745038
# p-value = 0.7538116866649766
# Нет статистически значимой разницы
# t - критерий =  1.0918706605434205
# p-value = 0.2749031092029706
# Нет статистически значимой разницы
# t - критерий =  -1.1840120734033002
# p-value = 0.23642235639446316
# Нет статистически значимой разницы
# t - критерий =  0.18216161422011973
# p-value = 0.8554577427210729
# Нет статистически значимой разницы
# t - критерий =  -0.1106020735707898
# p-value = 0.9119330129907397
# Нет статистически значимой разницы
# t - критерий =  0.5134466137723764
# p-value = 0.6076446181868574
# Нет статистически значимой разницы
# t - критерий =  0.19114577292116722
# p-value = 0.8484133275710761
# Нет статистически значимой разницы
# t - критерий =  0.6171536585391563
# p-value = 0.5371404051723726
# Нет статистически значимой разницы
# t - критерий =  0.5914632771866939
# p-value = 0.5542167390236752
# Нет статистически значимой разницы
# t - критерий =  -1.2885273368991823
# p-value = 0.19757736587818128
# Нет статистически значимой разницы
# t - критерий =  -1.2991311213768248
# p-value = 0.19391391191523588
# Нет статистически значимой разницы
# t - критерий =  -0.042562064863974076
# p-value = 0.9660510608424469
# Нет статистически значимой разницы
# t - критерий =  0.30140425193511755
# p-value = 0.7631093862422683
# Нет статистически значимой разницы
# t - критерий =  -0.3263649046033752
# p-value = 0.7441517024021207
# Нет статистически значимой разницы
# t - критерий =  -0.09272173213643847
# p-value = 0.9261255604388441
# Нет статистически значимой разницы
# t - критерий =  -0.6969370761136098
# p-value = 0.48585027472816233
# Нет статистически значимой разницы
# t - критерий =  0.9419532674591669
# p-value = 0.3462279449378708
# Нет статистически значимой разницы
# t - критерий =  0.13734235288623056
# p-value = 0.8907615775002844
# Нет статистически значимой разницы
# t - критерий =  0.9094479814199743
# p-value = 0.3631246646897661
# Нет статистически значимой разницы
# t - критерий =  -1.346732969024865
# p-value = 0.1780815118771339
# Нет статистически значимой разницы
# t - критерий =  0.007460967986926991
# p-value = 0.9940471384854735
# Нет статистически значимой разницы
# t - критерий =  -0.2829956954692619
# p-value = 0.7771830658359777
# Нет статистически значимой разницы
# t - критерий =  -0.1737093064377212
# p-value = 0.8620956814627868
# Нет статистически значимой разницы
# t - критерий =  0.8580861977085146
# p-value = 0.390855152095685
# Нет статистически значимой разницы
# t - критерий =  0.5327661939090796
# p-value = 0.5942013579062946
# Нет статистически значимой разницы
# t - критерий =  0.9612487154726651
# p-value = 0.33643874938348983
# Нет статистически значимой разницы
# t - критерий =  0.9353947183997248
# p-value = 0.3495962126320584
# Нет статистически значимой разницы
# t - критерий =  -0.962687913253829
# p-value = 0.33571580425127046
# Нет статистически значимой разницы
# t - критерий =  -0.9732050643477614
# p-value = 0.3304631655295327
# Нет статистически значимой разницы
# t - критерий =  0.29738276494525634
# p-value = 0.7661773893231855
# Нет статистически значимой разницы
# t - критерий =  0.6423007561125783
# p-value = 0.5206852863177369
# Нет статистически значимой разницы
# t - критерий =  0.010760087502761619
# p-value = 0.9914149653054831
# Нет статистически значимой разницы
# t - критерий =  0.2464586275525254
# p-value = 0.8053297568414016
# Нет статистически значимой разницы
# t - критерий =  -0.3635628274583339
# p-value = 0.7161883323059237
# Нет статистически значимой разницы
# t - критерий =  1.2902596638994188
# p-value = 0.19697543520005284
# Нет статистически значимой разницы
# t - критерий =  0.4776467283991364
# p-value = 0.6329068865434525
# Нет статистически значимой разницы
# t - критерий =  1.2552617926028968
# p-value = 0.20939840785084632
# Нет статистически значимой разницы
# t - критерий =  -1.0203576619658772
# p-value = 0.30757120886342026
# Нет статистически значимой разницы
# t - критерий =  0.34579225377732137
# p-value = 0.7295024844715385
# Нет статистически значимой разницы
# t - критерий =  0.05328731022258834
# p-value = 0.957503523079372
# Нет статистически значимой разницы
# t - критерий =  0.16421718019688067
# p-value = 0.8695618364902817
# Нет статистически значимой разницы
# t - критерий =  0.33647317799486176
# p-value = 0.7365176050508166
# 0

# %% [markdown]
# Нет пар выборок со значимыми различиями

# %% [markdown]
# Поправка Холма - Бонферрони

# %%
def ttest1(a,b):
    mean_diff = np.mean(a) - np.mean(b)
    n1 = len(a)
    n2 = len(b)
    sd_a = np.sqrt(np.var(a,ddof = 1))
    sd_b = np.sqrt(np.var(b,ddof = 1))
    sem = np.sqrt(sd_a**2/n1 + sd_b**2/n2)
    t = mean_diff/sem
    df = (n1 + n2) - 2
    return stats.t.cdf(-abs(t), df) * 2

# %%
values =[]
n = 20
for i in range(n):
    for j  in range(n):
        if i!=j & j < i:
            values.append(ttest1(df1[i],df1[j]))

# %%
sort_values = sorted(values)

# %%
def Holm_Bonferroni(data):
    j=0
    for i in data:
        if i > 0.05/(len(data) - (data.index(i) + 1) + 1):
            print ('Нет статистически значимой разницы','\ncorrected_p_value=',i/(len(data) - (data.index(i) + 1) + 1))
        else:
            print('Есть статистически значимая разница','\ncorrected_p_value=',i/(len(data) - (data.index(i) + 1) + 1))
            j+=1
    print(j)
    return j

# %%
Holm_Bonferroni(sort_values)/(n*(n-1)/2.0)
# Out:
# Есть статистически значимая разница
# corrected_p_value= 5.025151084403498e-91
# Есть статистически значимая разница
# corrected_p_value= 4.249117133353215e-87
# Есть статистически значимая разница
# corrected_p_value= 3.042087639088244e-85
# Есть статистически значимая разница
# corrected_p_value= 1.6155914321037366e-81
# Есть статистически значимая разница
# corrected_p_value= 2.539723850128257e-78
# Есть статистически значимая разница
# corrected_p_value= 2.932308930745769e-76
# Есть статистически значимая разница
# corrected_p_value= 4.7296988075108876e-73
# Есть статистически значимая разница
# corrected_p_value= 7.686502247145352e-73
# Есть статистически значимая разница
# corrected_p_value= 1.7354023201004795e-72
# Есть статистически значимая разница
# corrected_p_value= 2.5283788844443006e-67
# Есть статистически значимая разница
# corrected_p_value= 7.228278941520649e-65
# Есть статистически значимая разница
# corrected_p_value= 2.47961170584253e-59
# Есть статистически значимая разница
# corrected_p_value= 2.2836525881408804e-53
# Есть статистически значимая разница
# corrected_p_value= 1.2606723172329034e-50
# Есть статистически значимая разница
# corrected_p_value= 2.333943287375673e-45
# Есть статистически значимая разница
# corrected_p_value= 7.730321887625587e-44
# Есть статистически значимая разница
# corrected_p_value= 8.840975099311467e-44
# Есть статистически значимая разница
# corrected_p_value= 2.2101573382537892e-41
# Есть статистически значимая разница
# corrected_p_value= 2.370652880456139e-41
# Есть статистически значимая разница
# corrected_p_value= 7.35053421290828e-39
# Есть статистически значимая разница
# corrected_p_value= 2.0388089560506425e-38
# Есть статистически значимая разница
# corrected_p_value= 1.4933939294393506e-37
# Есть статистически значимая разница
# corrected_p_value= 2.8886636480194522e-36
# Есть статистически значимая разница
# corrected_p_value= 3.5011359699572846e-36
# Есть статистически значимая разница
# corrected_p_value= 3.2058150721739656e-35
# Есть статистически значимая разница
# corrected_p_value= 4.002848424164627e-34
# Есть статистически значимая разница
# corrected_p_value= 1.3998934444382934e-31
# Есть статистически значимая разница
# corrected_p_value= 3.5493117720559477e-31
# Есть статистически значимая разница
# corrected_p_value= 1.2691877404537065e-30
# Есть статистически значимая разница
# corrected_p_value= 2.2963370218777646e-29
# Есть статистически значимая разница
# corrected_p_value= 1.1198347523508364e-28
# Есть статистически значимая разница
# corrected_p_value= 2.5061597457856916e-28
# Есть статистически значимая разница
# corrected_p_value= 2.5769450700921305e-28
# Есть статистически значимая разница
# corrected_p_value= 6.512950957910283e-28
# Есть статистически значимая разница
# corrected_p_value= 1.2607419441103587e-26
# Есть статистически значимая разница
# corrected_p_value= 2.547022637137634e-26
# Есть статистически значимая разница
# corrected_p_value= 4.370195000394055e-25
# Есть статистически значимая разница
# corrected_p_value= 1.6824350258776053e-24
# Есть статистически значимая разница
# corrected_p_value= 4.1499253621888825e-24
# Есть статистически значимая разница
# corrected_p_value= 2.1748246692895903e-23
# Есть статистически значимая разница
# corrected_p_value= 3.5333087887227175e-23
# Есть статистически значимая разница
# corrected_p_value= 5.41589648335873e-23
# Есть статистически значимая разница
# corrected_p_value= 9.254911449990245e-23
# Есть статистически значимая разница
# corrected_p_value= 1.6058690162075399e-22
# Есть статистически значимая разница
# corrected_p_value= 2.498545900989477e-22
# Есть статистически значимая разница
# corrected_p_value= 1.1970714339413688e-21
# Есть статистически значимая разница
# corrected_p_value= 2.070224324499535e-21
# Есть статистически значимая разница
# corrected_p_value= 4.652382135433232e-21
# Есть статистически значимая разница
# corrected_p_value= 4.1807511267513595e-20
# Есть статистически значимая разница
# corrected_p_value= 1.1717456182751513e-19
# Есть статистически значимая разница
# corrected_p_value= 4.0362188968111713e-19
# Есть статистически значимая разница
# corrected_p_value= 1.2684206921975218e-18
# Есть статистически значимая разница
# corrected_p_value= 2.1145549860437293e-18
# Есть статистически значимая разница
# corrected_p_value= 3.9104454641493485e-18
# Есть статистически значимая разница
# corrected_p_value= 8.609268433493471e-18
# Есть статистически значимая разница
# corrected_p_value= 9.118280474401511e-18
# Есть статистически значимая разница
# corrected_p_value= 2.1758133367979382e-17
# Есть статистически значимая разница
# corrected_p_value= 3.202011004312768e-17
# Есть статистически значимая разница
# corrected_p_value= 4.599650725850326e-17
# Есть статистически значимая разница
# corrected_p_value= 2.402936620369629e-16
# Есть статистически значимая разница
# corrected_p_value= 2.825784831876657e-16
# Есть статистически значимая разница
# corrected_p_value= 5.3330387561973005e-15
# Есть статистически значимая разница
# corrected_p_value= 5.807570362637558e-15
# Есть статистически значимая разница
# corrected_p_value= 1.015090283434635e-14
# Есть статистически значимая разница
# corrected_p_value= 1.0712326008961175e-14
# Есть статистически значимая разница
# corrected_p_value= 1.5626806492800492e-14
# Есть статистически значимая разница
# corrected_p_value= 2.6027496404874583e-14
# Есть статистически значимая разница
# corrected_p_value= 3.97884163686016e-14
# Есть статистически значимая разница
# corrected_p_value= 4.635923472789665e-14
# Есть статистически значимая разница
# corrected_p_value= 6.718305661508926e-14
# Есть статистически значимая разница
# corrected_p_value= 7.81747488385718e-14
# Есть статистически значимая разница
# corrected_p_value= 8.656993180926376e-14
# Есть статистически значимая разница
# corrected_p_value= 2.1801466716625777e-13
# Есть статистически значимая разница
# corrected_p_value= 4.878498001540753e-13
# Есть статистически значимая разница
# corrected_p_value= 6.475809136808783e-13
# Есть статистически значимая разница
# corrected_p_value= 8.260700765499782e-13
# Есть статистически значимая разница
# corrected_p_value= 9.537583110139494e-13
# Есть статистически значимая разница
# corrected_p_value= 1.2207571013592343e-12
# Есть статистически значимая разница
# corrected_p_value= 3.74793219541122e-12
# Есть статистически значимая разница
# corrected_p_value= 7.537816444277415e-12
# Есть статистически значимая разница
# corrected_p_value= 8.489983650578e-12
# Есть статистически значимая разница
# corrected_p_value= 8.568846326189613e-12
# Есть статистически значимая разница
# corrected_p_value= 1.0867924150954876e-11
# Есть статистически значимая разница
# corrected_p_value= 1.1150778200895992e-11
# Есть статистически значимая разница
# corrected_p_value= 1.4053145365528685e-11
# Есть статистически значимая разница
# corrected_p_value= 1.9184724593249578e-11
# Есть статистически значимая разница
# corrected_p_value= 3.364087823136763e-11
# Есть статистически значимая разница
# corrected_p_value= 4.748607254355632e-11
# Есть статистически значимая разница
# corrected_p_value= 7.097897617060127e-11
# Есть статистически значимая разница
# corrected_p_value= 1.155082719062928e-10
# Есть статистически значимая разница
# corrected_p_value= 1.493348314456289e-10
# Есть статистически значимая разница
# corrected_p_value= 2.443815724332629e-10
# Есть статистически значимая разница
# corrected_p_value= 2.7239026675074986e-10
# Есть статистически значимая разница
# corrected_p_value= 4.5107861353254607e-10
# Есть статистически значимая разница
# corrected_p_value= 5.228265219523485e-10
# Есть статистически значимая разница
# corrected_p_value= 5.637148146907081e-10
# Есть статистически значимая разница
# corrected_p_value= 1.1392369438220353e-09
# Есть статистически значимая разница
# corrected_p_value= 3.081354276971095e-09
# Есть статистически значимая разница
# corrected_p_value= 5.937736615325555e-09
# Есть статистически значимая разница
# corrected_p_value= 7.666188550420236e-09
# Есть статистически значимая разница
# corrected_p_value= 9.873920500695129e-09
# Есть статистически значимая разница
# corrected_p_value= 1.0911095689102013e-08
# Есть статистически значимая разница
# corrected_p_value= 1.6832517338582555e-08
# Есть статистически значимая разница
# corrected_p_value= 1.7349214832178366e-08
# Есть статистически значимая разница
# corrected_p_value= 2.6656581900744574e-08
# Есть статистически значимая разница
# corrected_p_value= 2.7285867872637967e-08
# Есть статистически значимая разница
# corrected_p_value= 2.8401488511330994e-08
# Есть статистически значимая разница
# corrected_p_value= 4.4548036419789914e-08
# Есть статистически значимая разница
# corrected_p_value= 8.346591851784582e-08
# Есть статистически значимая разница
# corrected_p_value= 1.4121561197447464e-07
# Есть статистически значимая разница
# corrected_p_value= 2.66469420697966e-07
# Есть статистически значимая разница
# corrected_p_value= 2.784732838377838e-07
# Есть статистически значимая разница
# corrected_p_value= 7.331577836916499e-07
# Есть статистически значимая разница
# corrected_p_value= 7.56201298160262e-07
# Есть статистически значимая разница
# corrected_p_value= 9.226791588180309e-07
# Есть статистически значимая разница
# corrected_p_value= 9.548173773857492e-07
# Есть статистически значимая разница
# corrected_p_value= 2.1222891287263603e-06
# Есть статистически значимая разница
# corrected_p_value= 2.333146500379138e-06
# Есть статистически значимая разница
# corrected_p_value= 2.8816222280512627e-06
# Есть статистически значимая разница
# corrected_p_value= 4.269877676549544e-06
# Есть статистически значимая разница
# corrected_p_value= 1.0023488817525157e-05
# Нет статистически значимой разницы
# corrected_p_value= 1.2541363457033176e-05
# Нет статистически значимой разницы
# corrected_p_value= 1.4728581544053295e-05
# Нет статистически значимой разницы
# corrected_p_value= 1.7155023119130065e-05
# Нет статистически значимой разницы
# corrected_p_value= 3.2810913780406356e-05
# Нет статистически значимой разницы
# corrected_p_value= 3.4959271855550965e-05
# Нет статистически значимой разницы
# corrected_p_value= 4.61880671818937e-05
# Нет статистически значимой разницы
# corrected_p_value= 5.7562553486926995e-05
# Нет статистически значимой разницы
# corrected_p_value= 6.46445947755867e-05
# Нет статистически значимой разницы
# corrected_p_value= 6.62214824825889e-05
# Нет статистически значимой разницы
# corrected_p_value= 7.043284432690881e-05
# Нет статистически значимой разницы
# corrected_p_value= 7.285942338545354e-05
# Нет статистически значимой разницы
# corrected_p_value= 7.892727836878077e-05
# Нет статистически значимой разницы
# corrected_p_value= 8.120181014685326e-05
# Нет статистически значимой разницы
# corrected_p_value= 8.941121977860504e-05
# Нет статистически значимой разницы
# corrected_p_value= 0.00010157835077379553
# Нет статистически значимой разницы
# corrected_p_value= 0.00014430805043140328
# Нет статистически значимой разницы
# corrected_p_value= 0.00014959302111684027
# Нет статистически значимой разницы
# corrected_p_value= 0.00018125380641816644
# Нет статистически значимой разницы
# corrected_p_value= 0.00018547389330616793
# Нет статистически значимой разницы
# corrected_p_value= 0.00018944100944889608
# Нет статистически значимой разницы
# corrected_p_value= 0.0002018726112023183
# Нет статистически значимой разницы
# corrected_p_value= 0.00021505639024634404
# Нет статистически значимой разницы
# corrected_p_value= 0.0002631507096256059
# Нет статистически значимой разницы
# corrected_p_value= 0.0002935956191834577
# Нет статистически значимой разницы
# corrected_p_value= 0.00037895941428756037
# Нет статистически значимой разницы
# corrected_p_value= 0.0004444019011279511
# Нет статистически значимой разницы
# corrected_p_value= 0.0005082320763216505
# Нет статистически значимой разницы
# corrected_p_value= 0.0005854076543335428
# Нет статистически значимой разницы
# corrected_p_value= 0.0007094371349706382
# Нет статистически значимой разницы
# corrected_p_value= 0.0007983236592630863
# Нет статистически значимой разницы
# corrected_p_value= 0.0008887825350957507
# Нет статистически значимой разницы
# corrected_p_value= 0.0009734930246510038
# Нет статистически значимой разницы
# corrected_p_value= 0.0010315062981578768
# Нет статистически значимой разницы
# corrected_p_value= 0.0012965716198131089
# Нет статистически значимой разницы
# corrected_p_value= 0.0025724142494403255
# Нет статистически значимой разницы
# corrected_p_value= 0.0027214110164579986
# Нет статистически значимой разницы
# corrected_p_value= 0.0029008392254394892
# Нет статистически значимой разницы
# corrected_p_value= 0.0033591325723734103
# Нет статистически значимой разницы
# corrected_p_value= 0.004240879436863889
# Нет статистически значимой разницы
# corrected_p_value= 0.0049786237094491285
# Нет статистически значимой разницы
# corrected_p_value= 0.005552131844807912
# Нет статистически значимой разницы
# corrected_p_value= 0.008424468196108786
# Нет статистически значимой разницы
# corrected_p_value= 0.009252266454344772
# Нет статистически значимой разницы
# corrected_p_value= 0.010116929027476174
# Нет статистически значимой разницы
# corrected_p_value= 0.010970046495318981
# Нет статистически значимой разницы
# corrected_p_value= 0.01157254648938702
# Нет статистически значимой разницы
# corrected_p_value= 0.012292456594830742
# Нет статистически значимой разницы
# corrected_p_value= 0.013169079887690421
# Нет статистически значимой разницы
# corrected_p_value= 0.013948858357050202
# Нет статистически значимой разницы
# corrected_p_value= 0.01590893270396334
# Нет статистически значимой разницы
# corrected_p_value= 0.016857864608631524
# Нет статистически значимой разницы
# corrected_p_value= 0.017860431694839696
# Нет статистически значимой разницы
# corrected_p_value= 0.02016528566590364
# Нет статистически значимой разницы
# corrected_p_value= 0.024583679390379212
# Нет статистически значимой разницы
# corrected_p_value= 0.02785310566508863
# Нет статистически значимой разницы
# corrected_p_value= 0.030428392432550213
# Нет статистически значимой разницы
# corrected_p_value= 0.03319315221775621
# Нет статистически значимой разницы
# corrected_p_value= 0.03866110622672431
# Нет статистически значимой разницы
# corrected_p_value= 0.04265043897767893
# Нет статистически значимой разницы
# corrected_p_value= 0.048291717802252165
# Нет статистически значимой разницы
# corrected_p_value= 0.05832923320676099
# Нет статистически значимой разницы
# corrected_p_value= 0.0661187714580237
# Нет статистически значимой разницы
# corrected_p_value= 0.09760187167508382
# Нет статистически значимой разницы
# corrected_p_value= 0.11798819078583907
# Нет статистически значимой разницы
# corrected_p_value= 0.15743976686360098
# Нет статистически значимой разницы
# corrected_p_value= 0.2143538519813567
# Нет статистически значимой разницы
# corrected_p_value= 0.2902777655161371
# Нет статистически значимой разницы
# corrected_p_value= 0.46673215085493025
# Нет статистически значимой разницы
# corrected_p_value= 0.9471012120529426
# 121
# 0.6368421052631579

# %% [markdown]
# групп со значимыми различиями уже около 64%
